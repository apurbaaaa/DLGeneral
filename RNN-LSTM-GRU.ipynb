# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
from tensorflow.keras import layers, models, datasets

# %%
(train_data, train_labels), (test_data, test_labels) = tf.keras.datasets.imdb.load_data(num_words=10000)

# %%
max_len = 200
hidden = 64
embd_dim = 64
epochs = 3
num_words = 10000

# %%
x_train = pad_sequences(train_data, maxlen = max_len, truncating='pre')
x_test = pad_sequences(test_data, maxlen = max_len, truncating='pre')

# %%
rnn = models.Sequential([
    layers.Embedding(num_words, embd_dim, input_length = max_len),
    layers.SimpleRNN(hidden),
    layers.Dense(1, activation='sigmoid')
])
# Out:
# /Users/apurbakoirala/Developer/DLpractice/DLPractice/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
rnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
rnn.fit(x_train, train_labels, epochs = 3, validation_data=(x_test, test_labels), verbose = 2)
# Out:
# Epoch 1/3
# 782/782 - 13s - 17ms/step - accuracy: 0.6110 - loss: 0.6534 - val_accuracy: 0.7556 - val_loss: 0.5091
# Epoch 2/3
# 782/782 - 13s - 16ms/step - accuracy: 0.7426 - loss: 0.5220 - val_accuracy: 0.7391 - val_loss: 0.5242
# Epoch 3/3
# 782/782 - 13s - 16ms/step - accuracy: 0.7866 - loss: 0.4565 - val_accuracy: 0.7721 - val_loss: 0.4995

# %%
lstm = models.Sequential([
    layers.Embedding(num_words, embd_dim, input_length = max_len), 
    layers.LSTM(hidden),
    layers.Dense(1, activation='sigmoid')
])

# %%
lstm.compile(optimizer='adam', loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
lstm.fit(x_train, train_labels, epochs = 3, validation_data=(x_test, test_labels), verbose = 1)
# Out:
# Epoch 1/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 43ms/step - accuracy: 0.7932 - loss: 0.4300 - val_accuracy: 0.7669 - val_loss: 0.4875
# Epoch 2/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.8958 - loss: 0.2592 - val_accuracy: 0.8436 - val_loss: 0.4653
# Epoch 3/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.9282 - loss: 0.1903 - val_accuracy: 0.8405 - val_loss: 0.3703

# %%
gru = models.Sequential([
    layers.Embedding(num_words, embd_dim, input_length = max_len), 
    layers.GRU(hidden),
    layers.Dense(1, activation='sigmoid')
])

# %%
gru.compile(optimizer='adam', loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
gru.fit(x_train, train_labels, epochs = 3, validation_data=(x_test, test_labels), verbose = 1)
# Out:
# Epoch 1/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 43ms/step - accuracy: 0.8082 - loss: 0.4124 - val_accuracy: 0.8582 - val_loss: 0.3334
# Epoch 2/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.9052 - loss: 0.2372 - val_accuracy: 0.8808 - val_loss: 0.2914
# Epoch 3/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.9416 - loss: 0.1590 - val_accuracy: 0.8680 - val_loss: 0.3242

# %%
bi_lstm = models.Sequential([
    layers.Embedding(num_words, embd_dim, input_length = max_len), 
    layers.Bidirectional(layers.LSTM(hidden, return_sequences=False)),
    layers.Dense(1, activation='sigmoid')
])

# %%
bi_lstm.compile(optimizer='adam', loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
bi_lstm.fit(x_train, train_labels, epochs = 3, validation_data=(x_test, test_labels), verbose = 1)
# Out:
# Epoch 1/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 79ms/step - accuracy: 0.7970 - loss: 0.4393 - val_accuracy: 0.8554 - val_loss: 0.3476
# Epoch 2/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.8943 - loss: 0.2647 - val_accuracy: 0.8681 - val_loss: 0.3122
# Epoch 3/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9253 - loss: 0.1969 - val_accuracy: 0.8726 - val_loss: 0.3240
